# %% [markdown]
# ### Measurement Oscilloscope Binary Dataformat

# %%
import pandas as pd
import numpy as np
import scipy as sp
import pyarrow.parquet as pq
import time
import matplotlib.pyplot as plt
import argparse
import csv
import pyarrow as pa

# %%
import pkgutil
[m.name for m in pkgutil.iter_modules() if "rtx" in m.name.lower()] # finding the module names
# Out:
# ['RS_RTxReadBin_copy']

# %%
import RS_RTxReadBin as rb  # import the functionfrom RS_RTxReadBin.RTxReadBin import RTxReadBin  # import the function
from RS_RTxReadBin.RTxReadBin import RTxReadBin  # import the function
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import RS_RTxReadBin as rb  # import the functionfrom RS_RTxReadBin.RTxReadBin import RTxReadBin  # import the function
#       2 from RS_RTxReadBin.RTxReadBin import RTxReadBin  # import the function
#
# ModuleNotFoundError: No module named 'RS_RTxReadBin'
