# %%
from RsInstrument import RsInstrument

# %%
from RsInstrument import RsInstrument

# Note the different resource string: no ::INSTR, just host:port
resource = "TCPIP::192.168.10.2::5025::SOCKET"

scope = RsInstrument(resource,
                     reset=False,
                     id_query=True,
                     options="SelectVisa=socket")

print(scope.query_str("*IDN?"))
scope.close()
# Out:
# Rohde&Schwarz,RTO,1316.1000k44/400534,3.70.1.0

# %%
from RsInstrument import RsInstrument

resource = "TCPIP::192.168.10.2::5025::SOCKET"
scope = RsInstrument(resource,
                     reset=False,
                     id_query=True,
                     options="SelectVisa=socket")

print("Connected to:", scope.query_str("*IDN?"))

# Clear status only; no CHAN or ACQ commands
scope.write_str("*CLS")

# Use whatever channel/trigger/timebase you already set on the front panel.
# Just tell export to use the full waveform:
scope.write_str("EXPort:WAVeform:SCOPe WFM")

n_files = 1          # start with 1 file for testing
acq_per_file = 10    # 10 singles per file
usb_root = "D:"      # check that your USB stick is D: on the scope

for i in range(n_files):
    print(f"Acquiring block {i+1}/{n_files} with {acq_per_file} acquisitions")

    # Let the scope acquire N single shots using its current settings
    for n in range(acq_per_file):
        scope.write_str("SINGle")
        scope.write_str("*WAI")     # wait for this acquisition to finish

    # Build filename, e.g. D:\Run_000.bin
    fname = f"{usb_root}\\Remote_Run_{i:03d}.bin"
    print("Exporting to", fname)

    # Set export file name and format (extension .bin → binary)
    scope.write_str(f"EXPort:WAVeform:NAME '{fname}'")

    # Start the export
    scope.write_str("EXPort:WAVeform:SAVE")

    # Wait until export is complete
    scope.query_str("*OPC?")       # returns "1" when done

print("Done.")
scope.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 from RsInstrument import RsInstrument
#       3 resource = "TCPIP::192.168.10.2::5025::SOCKET"
# ----> 4 scope = RsInstrument(resource,
#       5                      reset=False,
#       6                      id_query=True,
#       7                      options="SelectVisa=socket")
#       9 print("Connected to:", scope.query_str("*IDN?"))
#      11 # Clear status only; no CHAN or ACQ commands
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/RsInstrument.py:82, in RsInstrument.__init__(self, resource_name, id_query, reset, options, direct_session)
#      30 		"""Initializes new RsInstrument session. \n
#      31
#      32 		:param resource_name: VISA resource name, e.g. 'TCPIP::192.168.2.1::INSTR'
#    (...)     78 			- ``LoggingRelativeTimeOfFirstEntry = True`` - Logging starts with relative time set to the first log entry, which causes the first start time to be '00:00:00.000'. Default: False
#      79 """
#      81 		GlobalData.bounded_class = RsInstrument
# ---> 82 		self._core = Core(
#      83 			resource_name,
#      84 			id_query,
#      85 			reset,
#      86 			driver_options=RsInstrument._driver_options_const,
#      87 			user_options=options,
#      88 			direct_session=direct_session,
#      89 			called_from_driver=False)
#      90 		self._core.driver_version = RsInstrument._driver_version_const
#      91 		# Custom interfaces
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/Core.py:303, in Core.__init__(self, resource_name, id_query, reset, driver_options, user_options, direct_session, called_from_driver)
#     301 self._args_single_list = ArgSingleList()
#     302 handle = self._resolve_direct_session(direct_session)
# --> 303 self.io = Instrument(self.resource_name, self.simulating, self._instrumentSettings, handle)
#     304 self.io.query_instr_status = True
#     305 self.io.called_from_driver = self.called_from_driver
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/Instrument.py:96, in Instrument.__init__(self, resource_name, simulate, settings, direct_session)
#      93 	self._log_end_segment()
#      94 	return
# ---> 96 self._set_session(VisaSession(resource_name, self._settings, direct_session))
#      97 self._init_logger(self._session.resource_name)
#      98 self._log_start_segment(direct_start_time)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/VisaSession.py:117, in VisaSession.__init__(self, resource_name, settings, direct_session)
#     115 try:
#     116 	acc_mode = pyvisa.constants.AccessModes.no_lock if settings.exclusive_lock is False else pyvisa.constants.AccessModes.exclusive_lock
# --> 117 	self._session = self._rm.open_resource(resource_name=pure_resource_name, open_timeout=settings.open_timeout, access_mode=acc_mode)
#     118 except pyvisa.VisaIOError as e:
#     119 	if e.error_code != pyvisa.constants.StatusCode.error_resource_not_found:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/VisaPluginSocketIo.py:192, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout)
#     190 """Creates new Socket connection. access_mode and open_timeout are here for compatibility reasons with the pyvisa rm.open_resource()"""
#     191 self.connection = SocketIo(resource_name)
# --> 192 self.connection.connect()
#     193 return self.connection
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/VisaPluginSocketIo.py:31, in SocketIo.connect(self)
#      29 def connect(self):
#      30 	"""Connects to the server (IP address and port number)"""
# ---> 31 	self.session.connect((self.host, self.port))
#
# KeyboardInterrupt:

# %%
from RsInstrument import RsInstrument
import numpy as np

scope = RsInstrument("TCPIP::192.168.10.2::5025::SOCKET",
                     reset=False,
                     id_query=True,
                     options="SelectVisa=socket")

# Configure waveform format
scope.write_str("FORMat:DATA REAL,64")
scope.write_str("WAVeform:SOURce CHAN1")
scope.write_str("WAVeform:POINts:MODE RAW")

n_acq = 10_000
batch_size = 1000

for batch_start in range(0, n_acq, batch_size):
    this_batch = min(batch_size, n_acq - batch_start)
    traces = []

    for i in range(this_batch):
        scope.write_str("SINGle")
        scope.write_str("*WAI")

        y = scope.query_bin_or_ascii_real("WAVeform:DATA?")
        y = np.array(y)

        xinc = float(scope.query_str("WAVeform:XINCrement?"))
        xorig = float(scope.query_str("WAVeform:XORigin?"))
        n = len(y)
        x = xorig + xinc * np.arange(n)

        # either:
        # 1) accumulate for saving:
        traces.append(y)
        # or 2) immediately compute jitter/charge here and append just scalars

    traces = np.column_stack(traces)  # (n_samples, this_batch)

    # Save batch compactly or process and discard
    np.savez_compressed(f"/Users/laloscola/ExternalDrive/run_batch_{batch_start:07d}.npz", x=x, y=traces)
    # or call your analyze_run_large(x, traces, ...) here

scope.close()
# Out:
# ---------------------------------------------------------------------------
# StatusException                           Traceback (most recent call last)
# Cell In[16], line 10
#       4 scope = RsInstrument("TCPIP::192.168.10.2::5025::SOCKET",
#       5                      reset=False,
#       6                      id_query=True,
#       7                      options="SelectVisa=socket")
#       9 # Configure waveform format
# ---> 10 scope.write_str("FORMat:DATA REAL,64")
#      11 scope.write_str("WAVeform:SOURce CHAN1")
#      12 scope.write_str("WAVeform:POINts:MODE RAW")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/RsInstrument.py:449, in RsInstrument.write_str(self, cmd)
#     446 def write_str(self, cmd: str) -> None:
#     447 	"""Writes the command to the instrument as string.
#     448 	This method is an alias to write() method."""
# --> 449 	self._core.io.write(cmd, log_info='Write')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/Instrument.py:728, in Instrument.write(self, cmd, block_callback, log_info)
#     726 		self.send_write_str_event(cmd, False)
#     727 	self._log_info(log_info, cmd, cmd)
# --> 728 	self.check_status()
#     729 except RsInstrException as e:
#     730 	self._log_exception(e, cmd, log_info)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/Instrument.py:667, in Instrument.check_status(self)
#     664 """Throws InstrumentStatusException in case of an error in the instrument's error queue.
#     665 The procedure is skipped, if the QueryInstrumentStatus is set to false."""
#     666 if self.query_instr_status:
# --> 667 	self.check_status_always(self.logger.log_status_check_ok)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/Instrument.py:653, in Instrument.check_status_always(self, log_ok_result)
#     651 if call_syst_error:
#     652 	errors = self.query_all_syst_errors(enable_log=False)
# --> 653 	assert_no_instrument_status_errors(self.resource_name, errors)
#     654 end_time = datetime.now()
#     655 if log_ok_result:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/measureoscill/lib/python3.12/site-packages/RsInstrument/Internal/InstrumentErrors.py:73, in assert_no_instrument_status_errors(rsrc_name, errors, context, first_exc)
#      71 msg = get_instrument_status_errors(rsrc_name, errors, context)
#      72 if msg:
# ---> 73 	raise StatusException(rsrc_name, msg, errors, first_exc=first_exc)
#
# StatusException: 'TCPIP::192.168.10.2::5025::SOCKET': Instrument error detected: -222,"Data out of range;FORMat:DATA REAL,64"

# %%
from RsInstrument import RsInstrument
import time

resource = "TCPIP::192.168.10.2::5025::SOCKET"
scope = RsInstrument(resource,
                     reset=False,
                     id_query=True,
                     options="SelectVisa=socket")

print("Connected to:", scope.query_str("*IDN?"))

# Assume: data logging mode and file settings are already configured on the front panel.
# This script only starts logging, waits for it to finish, and repeats.

n_runs = 1   # number of logging runs you want

for i in range(n_runs):
    print(f"Starting logging run {i+1}/{n_runs}")

    # Start acquisition/logging (equivalent to RUN CONT)
    scope.write_str("RUN")

    # Option A: wait until the scope signals completion via *OPC?
    # (works if the logging operation is treated as an overlapped operation)
    scope.query_str("*OPC?")   # blocks until the operation completes

    # Option B: if *OPC? doesn't reflect logging completion, you can:
    # - sleep for a known duration, or
    # - poll a logging status register defined in the manual.

    print(f"Logging run {i+1} finished")

print("All runs done.")
scope.close()
# Out:
# Connected to: Rohde&Schwarz,RTO,1316.1000k44/400534,3.70.1.0
# Starting logging run 1/1
# Logging run 1 finished
# All runs done.

# %%
from RsInstrument import RsInstrument
import time
# ------------- working code to tell the RTO 1044 to take n_files # with acq_per_file # in data logging mode ---------
'''1. connect via LAN cable to RTO
2. on RTO select IP: 192.168.10.2 and local mask: 255.255.255.0
3. on Mac under Network select manually IP:  192.168.10.1 and local mask: 255.255.255.0 
4. select wanted n_files, acq_per_file, usb_root and wait_s -> typically for 1000 acq's at 1ps resolution: wait_s ~ 30s
5. run script
'''
resource = "TCPIP::192.168.10.2::5025::SOCKET"
scope = RsInstrument(resource,
                     reset=False,
                     id_query=True,
                     options="SelectVisa=socket")

print("Connected to:", scope.query_str("*IDN?"))

scope.write_str("*CLS")

n_files = 100         # number of log files
acq_per_file = 5000   # waveforms per file
usb_root = "D:"
wait_s = 150           # rough time estimate per run (adjust as needed)

for i in range(n_files):
    print(f"Configuring data logging run {i+1}/{n_files}")

    scope.write_str(f"ACQuire:COUNt {acq_per_file}")
    scope.write_str("EXPort:WAVeform:DLOGging ON")
    scope.write_str("EXPort:WAVeform:TIMestamps ON")

    fname = f"{usb_root}\\Run_{i:03d}.bin"
    scope.write_str(f"EXPort:WAVeform:NAME '{fname}'")

    print("Starting RUNSingle")
    scope.write_str("RUNSingle")

    # Just wait long enough for acquisition + logging to finish
    print(f"Sleeping {wait_s} s while logging...")
    time.sleep(wait_s)

    print(f"Finished run {i+1}, file {fname}")

scope.close()
# Out:
# Connected to: Rohde&Schwarz,RTO,1316.1000k44/400534,3.70.1.0
# Configuring data logging run 1/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 1, file D:\Run_000.bin
# Configuring data logging run 2/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 2, file D:\Run_001.bin
# Configuring data logging run 3/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 3, file D:\Run_002.bin
# Configuring data logging run 4/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 4, file D:\Run_003.bin
# Configuring data logging run 5/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 5, file D:\Run_004.bin
# Configuring data logging run 6/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 6, file D:\Run_005.bin
# Configuring data logging run 7/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 7, file D:\Run_006.bin
# Configuring data logging run 8/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 8, file D:\Run_007.bin
# Configuring data logging run 9/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 9, file D:\Run_008.bin
# Configuring data logging run 10/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 10, file D:\Run_009.bin
# Configuring data logging run 11/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 11, file D:\Run_010.bin
# Configuring data logging run 12/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 12, file D:\Run_011.bin
# Configuring data logging run 13/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 13, file D:\Run_012.bin
# Configuring data logging run 14/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 14, file D:\Run_013.bin
# Configuring data logging run 15/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 15, file D:\Run_014.bin
# Configuring data logging run 16/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 16, file D:\Run_015.bin
# Configuring data logging run 17/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 17, file D:\Run_016.bin
# Configuring data logging run 18/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 18, file D:\Run_017.bin
# Configuring data logging run 19/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 19, file D:\Run_018.bin
# Configuring data logging run 20/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 20, file D:\Run_019.bin
# Configuring data logging run 21/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 21, file D:\Run_020.bin
# Configuring data logging run 22/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 22, file D:\Run_021.bin
# Configuring data logging run 23/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 23, file D:\Run_022.bin
# Configuring data logging run 24/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 24, file D:\Run_023.bin
# Configuring data logging run 25/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 25, file D:\Run_024.bin
# Configuring data logging run 26/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 26, file D:\Run_025.bin
# Configuring data logging run 27/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 27, file D:\Run_026.bin
# Configuring data logging run 28/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 28, file D:\Run_027.bin
# Configuring data logging run 29/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 29, file D:\Run_028.bin
# Configuring data logging run 30/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 30, file D:\Run_029.bin
# Configuring data logging run 31/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 31, file D:\Run_030.bin
# Configuring data logging run 32/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 32, file D:\Run_031.bin
# Configuring data logging run 33/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 33, file D:\Run_032.bin
# Configuring data logging run 34/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 34, file D:\Run_033.bin
# Configuring data logging run 35/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 35, file D:\Run_034.bin
# Configuring data logging run 36/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 36, file D:\Run_035.bin
# Configuring data logging run 37/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 37, file D:\Run_036.bin
# Configuring data logging run 38/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 38, file D:\Run_037.bin
# Configuring data logging run 39/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 39, file D:\Run_038.bin
# Configuring data logging run 40/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 40, file D:\Run_039.bin
# Configuring data logging run 41/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 41, file D:\Run_040.bin
# Configuring data logging run 42/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 42, file D:\Run_041.bin
# Configuring data logging run 43/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 43, file D:\Run_042.bin
# Configuring data logging run 44/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 44, file D:\Run_043.bin
# Configuring data logging run 45/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 45, file D:\Run_044.bin
# Configuring data logging run 46/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 46, file D:\Run_045.bin
# Configuring data logging run 47/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 47, file D:\Run_046.bin
# Configuring data logging run 48/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 48, file D:\Run_047.bin
# Configuring data logging run 49/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 49, file D:\Run_048.bin
# Configuring data logging run 50/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 50, file D:\Run_049.bin
# Configuring data logging run 51/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 51, file D:\Run_050.bin
# Configuring data logging run 52/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 52, file D:\Run_051.bin
# Configuring data logging run 53/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 53, file D:\Run_052.bin
# Configuring data logging run 54/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 54, file D:\Run_053.bin
# Configuring data logging run 55/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 55, file D:\Run_054.bin
# Configuring data logging run 56/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 56, file D:\Run_055.bin
# Configuring data logging run 57/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 57, file D:\Run_056.bin
# Configuring data logging run 58/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 58, file D:\Run_057.bin
# Configuring data logging run 59/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 59, file D:\Run_058.bin
# Configuring data logging run 60/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 60, file D:\Run_059.bin
# Configuring data logging run 61/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 61, file D:\Run_060.bin
# Configuring data logging run 62/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 62, file D:\Run_061.bin
# Configuring data logging run 63/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 63, file D:\Run_062.bin
# Configuring data logging run 64/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 64, file D:\Run_063.bin
# Configuring data logging run 65/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 65, file D:\Run_064.bin
# Configuring data logging run 66/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 66, file D:\Run_065.bin
# Configuring data logging run 67/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 67, file D:\Run_066.bin
# Configuring data logging run 68/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 68, file D:\Run_067.bin
# Configuring data logging run 69/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 69, file D:\Run_068.bin
# Configuring data logging run 70/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 70, file D:\Run_069.bin
# Configuring data logging run 71/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 71, file D:\Run_070.bin
# Configuring data logging run 72/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 72, file D:\Run_071.bin
# Configuring data logging run 73/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 73, file D:\Run_072.bin
# Configuring data logging run 74/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 74, file D:\Run_073.bin
# Configuring data logging run 75/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 75, file D:\Run_074.bin
# Configuring data logging run 76/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 76, file D:\Run_075.bin
# Configuring data logging run 77/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 77, file D:\Run_076.bin
# Configuring data logging run 78/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 78, file D:\Run_077.bin
# Configuring data logging run 79/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 79, file D:\Run_078.bin
# Configuring data logging run 80/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 80, file D:\Run_079.bin
# Configuring data logging run 81/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 81, file D:\Run_080.bin
# Configuring data logging run 82/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 82, file D:\Run_081.bin
# Configuring data logging run 83/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 83, file D:\Run_082.bin
# Configuring data logging run 84/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 84, file D:\Run_083.bin
# Configuring data logging run 85/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 85, file D:\Run_084.bin
# Configuring data logging run 86/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 86, file D:\Run_085.bin
# Configuring data logging run 87/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 87, file D:\Run_086.bin
# Configuring data logging run 88/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 88, file D:\Run_087.bin
# Configuring data logging run 89/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 89, file D:\Run_088.bin
# Configuring data logging run 90/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 90, file D:\Run_089.bin
# Configuring data logging run 91/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 91, file D:\Run_090.bin
# Configuring data logging run 92/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 92, file D:\Run_091.bin
# Configuring data logging run 93/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 93, file D:\Run_092.bin
# Configuring data logging run 94/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 94, file D:\Run_093.bin
# Configuring data logging run 95/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 95, file D:\Run_094.bin
# Configuring data logging run 96/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 96, file D:\Run_095.bin
# Configuring data logging run 97/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 97, file D:\Run_096.bin
# Configuring data logging run 98/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 98, file D:\Run_097.bin
# Configuring data logging run 99/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 99, file D:\Run_098.bin
# Configuring data logging run 100/100
# Starting RUNSingle
# Sleeping 150 s while logging...
# Finished run 100, file D:\Run_099.bin
